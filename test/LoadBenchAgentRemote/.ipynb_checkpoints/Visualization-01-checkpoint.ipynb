# %%
import datetime
import pandas as pd
import numpy as np
from pandas import DataFrame
# %matplotlib inline

# %%
df = pd.read_csv('experiments_results_02.csv')

# %%
df.drop('Balanced', axis=1, inplace=True)
df.drop('Backup', axis=1, inplace=True)
df.head()
# Out:
#    Nodes  Agents  SmallTasks  MedTasks  BigTasks  Order  Cooperation   Time
# 0      2   15000        2500      1000      5000      1            1  12019
# 1      2   15000        1000      1000      1000      1            1  11606
# 2      4   15000        1000      2500      1000      0            0  10464
# 3      2     100        1000      5000      2500      1            0   3352
# 4      1     100        1000      1000      5000      0            0   2186

# %%
df.describe()
# Out:
#              Nodes        Agents   SmallTasks     MedTasks     BigTasks  \
# count  3888.000000   3888.000000  3888.000000  3888.000000  3888.000000
# mean      2.333333   6700.000000  2833.333333  2833.333333  2833.333333
# std       1.247380   6201.335159  1650.128044  1650.128044  1650.128044
# min       1.000000    100.000000  1000.000000  1000.000000  1000.000000
# 25%       1.000000    100.000000  1000.000000  1000.000000  1000.000000
# 50%       2.000000   5000.000000  2500.000000  2500.000000  2500.000000
# 75%       4.000000  15000.000000  5000.000000  5000.000000  5000.000000
# max       4.000000  15000.000000  5000.000000  5000.000000  5000.000000
#
#              Order  Cooperation          Time
# count  3888.000000  3888.000000   3888.000000
# mean      0.500000     0.500000   7715.264146
# std       0.500064     0.500064   4524.839344
# min       0.000000     0.000000   1848.000000
# 25%       0.000000     0.000000   3908.750000
# 50%       0.500000     0.500000   6571.000000
# 75%       1.000000     1.000000  10641.750000
# max       1.000000     1.000000  60135.000000

# %%
result_df1 = df[df.Cooperation.eq(0)]
result_df1 = result_df1.groupby(["Nodes", "Agents","SmallTasks","MedTasks","BigTasks","Order","Cooperation"], as_index=False).mean().groupby(["Agents","Nodes"])['Time'].mean()

# %%
result_df2 = df[df.Cooperation.eq(1)]
result_df2 = result_df2.groupby(["Nodes", "Agents","SmallTasks","MedTasks","BigTasks","Order","Cooperation"], as_index=False).mean().groupby(["Agents","Nodes"])['Time'].mean()

# %%
result_df3 = df[df.Order.eq(0)]
result_df3 = result_df3.groupby(["Nodes", "Agents","SmallTasks","MedTasks","BigTasks","Order","Cooperation"], as_index=False).mean().groupby(["Agents","Nodes","Order"])['Time'].mean()

# %%
result_df4 = df[df.Order.eq(1)]
result_df4 = result_df4.groupby(["Nodes", "Agents","SmallTasks","MedTasks","BigTasks","Order","Cooperation"], as_index=False).mean().groupby(["Agents","Nodes","Order"])['Time'].mean()

# %%
#Sin Cooperación
result_df1
# Out:
# Agents  Nodes
# 100     1         2549.796296
#         2         2702.384259
#         4         3288.263889
# 5000    1         6693.648148
#         2         5442.912037
#         4         7293.675926
# 15000   1        18399.643519
#         2        11432.685185
#         4        11163.824074
# Name: Time, dtype: float64

# %%
#Con Cooperación
result_df2
# Out:
# Agents  Nodes
# 100     1         3252.916667
#         2         3817.074074
#         4         5075.351852
# 5000    1         5947.370370
#         2         7008.583333
#         4         8809.398148
# 15000   1        10006.740741
#         2        11481.194444
#         4        14509.291667
# Name: Time, dtype: float64

# %%
result_df3
# Out:
# Agents  Nodes  Order
# 100     1      0         2718.574074
#         2      0         3090.675926
#         4      0         4035.254630
# 5000    1      0         6213.685185
#         2      0         6023.083333
#         4      0         7192.166667
# 15000   1      0        13896.074074
#         2      0        11230.796296
#         4      0        12535.361111
# Name: Time, dtype: float64

# %%
result_df4
# Out:
# Agents  Nodes  Order
# 100     1      1         3084.138889
#         2      1         3428.782407
#         4      1         4328.361111
# 5000    1      1         6427.333333
#         2      1         6428.412037
#         4      1         8910.907407
# 15000   1      1        14510.310185
#         2      1        11683.083333
#         4      1        13137.754630
# Name: Time, dtype: float64

# %%
result_df1.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Agents,Nodes'>

# %%
result_df2.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Agents,Nodes'>

# %%
result_df3.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Agents,Nodes,Order'>

# %%
result_df4.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Agents,Nodes,Order'>
