# %%
import datetime
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
df = pd.read_csv('experiments_results.txt')

# %%
df["Time"].describe()
# Out:
# count      177.000000
# mean      6616.757062
# std       4698.034317
# min       1803.000000
# 25%       2833.000000
# 50%       5363.000000
# 75%       9292.000000
# max      29607.000000
# Name: Time, dtype: float64

# %%
result_df = df.Time.groupby(df.Nodes)

# %%
result_df.describe()
# Out:
#        count         mean          std     min     25%     50%      75%  \
# Nodes
# 1       59.0  8356.711864  6727.147026  1803.0  2414.0  5807.0  16042.5
# 2       59.0  5681.067797  3162.678856  2065.0  2377.0  4845.0   9316.0
# 4       59.0  5812.491525  2662.776146  2723.0  2988.5  5293.0   8605.5
#
#            max
# Nodes
# 1      29607.0
# 2      10921.0
# 4      10752.0

# %%
result_df.plot.line(figsize=(20,10))
# Out:
# Nodes
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# 2    AxesSubplot(0.125,0.125;0.775x0.755)
# 4    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Time, dtype: object
